# %%
import pandas as pd

# %%
! pip install alpha_vantage
# Out:
# Requirement already satisfied: alpha_vantage in c:\users\charls\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: requests in c:\users\charls\anaconda3\lib\site-packages (from alpha_vantage) (2.28.1)
# Requirement already satisfied: aiohttp in c:\users\charls\anaconda3\lib\site-packages (from alpha_vantage) (3.8.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (1.9.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (21.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (1.3.1)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (4.0.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\charls\anaconda3\lib\site-packages (from aiohttp->alpha_vantage) (6.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\charls\anaconda3\lib\site-packages (from requests->alpha_vantage) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\charls\anaconda3\lib\site-packages (from requests->alpha_vantage) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\charls\anaconda3\lib\site-packages (from requests->alpha_vantage) (1.26.11)

# %%
from alpha_vantage.timeseries import TimeSeries

# %%
key='R9UYE8ZUY92XLTUM'

# %%
ts = TimeSeries(key=key,output_format='pandas')

# %%
find='SPY'

# %%
data, meta_data = ts.get_daily_adjusted(symbol=find, outputsize='full')

# %%
data
# Out:
#                1. open     2. high      3. low    4. close  5. adjusted close  \
# date
# 2023-04-21  412.190000  412.680000  410.170000  412.200000         412.200000
# 2023-04-20  411.210000  413.700000  410.270000  411.880000         411.880000
# 2023-04-19  412.220000  415.080000  412.160000  414.140000         414.140000
# 2023-04-18  415.580000  415.720000  412.780200  414.210000         414.210000
# 2023-04-17  412.370000  413.960000  411.085000  413.940000         413.940000
# ...                ...         ...         ...         ...                ...
# 1999-11-05  138.625000  139.109299  136.781204  137.875000          89.722043
# 1999-11-04  136.750000  137.359299  135.765594  136.531204          88.847568
# 1999-11-03  136.000000  136.375000  135.125000  135.500000          88.176513
# 1999-11-02  135.968704  137.250000  134.593704  134.593704          87.586742
# 1999-11-01  136.500000  137.000000  135.562500  135.562500          88.217185
#
#              6. volume  7. dividend amount  8. split coefficient
# date
# 2023-04-21  73457422.0                 0.0                   1.0
# 2023-04-20  75840359.0                 0.0                   1.0
# 2023-04-19  55227330.0                 0.0                   1.0
# 2023-04-18  63559997.0                 0.0                   1.0
# 2023-04-17  65496534.0                 0.0                   1.0
# ...                ...                 ...                   ...
# 1999-11-05   7431500.0                 0.0                   1.0
# 1999-11-04   7907500.0                 0.0                   1.0
# 1999-11-03   7222300.0                 0.0                   1.0
# 1999-11-02   6516900.0                 0.0                   1.0
# 1999-11-01   4006500.0                 0.0                   1.0
#
# [5906 rows x 8 columns]

# %%
data = data.loc['2020-01-22':'2023-03-29']

# %%
data=data.iloc[:,1:3]

# %%
date=[]
for i in data.index:
  date.append(i)

# %%
data['date']=date

# %%
data['date']=data['date'].dt.strftime('%-m/%-d/%-y')

# %%
stock = data.reset_index(drop = True)

# %%
stock
# Out:
#      2. high  3. low                 date
# 0     401.60  398.68  2023-03-29 00:00:00
# 1     396.49  393.69  2023-03-28 00:00:00
# 2     398.92  395.56  2023-03-27 00:00:00
# 3     395.84  389.40  2023-03-24 00:00:00
# 4     399.29  390.35  2023-03-23 00:00:00
# ..       ...     ...                  ...
# 798   327.85  323.60  2020-01-28 00:00:00
# 799   325.12  322.66  2020-01-27 00:00:00
# 800   332.53  327.36  2020-01-24 00:00:00
# 801   332.17  329.41  2020-01-23 00:00:00
# 802   332.95  331.17  2020-01-22 00:00:00
#
# [803 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv',on_bad_lines='skip')

# %%
df2 = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv',on_bad_lines='skip')

# %%
df
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# 0          0        0        0        0        0  ...   209322  209340
# 1          0        0        0        0        0  ...   334391  334408
# 2          0        0        0        0        0  ...   271441  271448
# 3          0        0        0        0        0  ...    47866   47875
# 4          0        0        0        0        0  ...   105255  105277
# ..       ...      ...      ...      ...      ...  ...      ...     ...
# 284        0        0        0        0        0  ...   703228  703228
# 285        0        0        0        0        0  ...      535     535
# 286        0        0        0        0        0  ...    11945   11945
# 287        0        0        0        0        0  ...   343012  343012
# 288        0        0        0        0        0  ...   263921  264127
#
#      3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0    209358  209362  209369  209390  209406  209436  209451  209451
# 1    334408  334427  334427  334427  334427  334427  334443  334457
# 2    271463  271469  271469  271477  271477  271490  271494  271496
# 3     47875   47875   47875   47875   47875   47875   47890   47890
# 4    105277  105277  105277  105277  105277  105277  105288  105288
# ..      ...     ...     ...     ...     ...     ...     ...     ...
# 284  703228  703228  703228  703228  703228  703228  703228  703228
# 285     535     535     535     535     535     535     535     535
# 286   11945   11945   11945   11945   11945   11945   11945   11945
# 287  343079  343079  343079  343135  343135  343135  343135  343135
# 288  264127  264127  264127  264127  264127  264127  264276  264276
#
# [289 rows x 1147 columns]

# %%
df.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '2/28/23', '3/1/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23',
#        '3/7/23', '3/8/23', '3/9/23'],
#       dtype='object', length=1147)

# %%
df2.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '2/28/23', '3/1/23', '3/2/23', '3/3/23', '3/4/23', '3/5/23', '3/6/23',
#        '3/7/23', '3/8/23', '3/9/23'],
#       dtype='object', length=1147)

# %%
df2
# Out:
#     Province/State        Country/Region        Lat        Long  1/22/20  \
# 0              NaN           Afghanistan  33.939110   67.709953        0
# 1              NaN               Albania  41.153300   20.168300        0
# 2              NaN               Algeria  28.033900    1.659600        0
# 3              NaN               Andorra  42.506300    1.521800        0
# 4              NaN                Angola -11.202700   17.873900        0
# ..             ...                   ...        ...         ...      ...
# 284            NaN    West Bank and Gaza  31.952200   35.233200        0
# 285            NaN  Winter Olympics 2022  39.904200  116.407400        0
# 286            NaN                 Yemen  15.552727   48.516388        0
# 287            NaN                Zambia -13.133897   27.849332        0
# 288            NaN              Zimbabwe -19.015438   29.154857        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  2/28/23  3/1/23  \
# 0          0        0        0        0        0  ...     7896    7896
# 1          0        0        0        0        0  ...     3598    3598
# 2          0        0        0        0        0  ...     6881    6881
# 3          0        0        0        0        0  ...      165     165
# 4          0        0        0        0        0  ...     1933    1933
# ..       ...      ...      ...      ...      ...  ...      ...     ...
# 284        0        0        0        0        0  ...     5708    5708
# 285        0        0        0        0        0  ...        0       0
# 286        0        0        0        0        0  ...     2159    2159
# 287        0        0        0        0        0  ...     4057    4057
# 288        0        0        0        0        0  ...     5663    5668
#
#      3/2/23  3/3/23  3/4/23  3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# 0      7896    7896    7896    7896    7896    7896    7896    7896
# 1      3598    3598    3598    3598    3598    3598    3598    3598
# 2      6881    6881    6881    6881    6881    6881    6881    6881
# 3       165     165     165     165     165     165     165     165
# 4      1933    1933    1933    1933    1933    1933    1933    1933
# ..      ...     ...     ...     ...     ...     ...     ...     ...
# 284    5708    5708    5708    5708    5708    5708    5708    5708
# 285       0       0       0       0       0       0       0       0
# 286    2159    2159    2159    2159    2159    2159    2159    2159
# 287    4057    4057    4057    4057    4057    4057    4057    4057
# 288    5668    5668    5668    5668    5668    5668    5671    5671
#
# [289 rows x 1147 columns]

# %%
df.isna().sum()
# Out:
# Province/State    198
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 3/5/23              0
# 3/6/23              0
# 3/7/23              0
# 3/8/23              0
# 3/9/23              0
# Length: 1147, dtype: int64

# %%
df2.isna().sum()
# Out:
# Province/State    198
# Country/Region      0
# Lat                 2
# Long                2
# 1/22/20             0
#                  ...
# 3/5/23              0
# 3/6/23              0
# 3/7/23              0
# 3/8/23              0
# 3/9/23              0
# Length: 1147, dtype: int64

# %%
df['Province/State']=df['Province/State'].fillna(df['Province/State'].mode() [0])
df['Lat']=df['Lat'].fillna(df['Lat'].mode() [0])
df['Long']=df['Long'].fillna(df['Long'].mode() [0])
df2['Province/State']=df2['Province/State'].fillna(df2['Province/State'].mode() [0])
df2['Lat']=df2['Lat'].fillna(df2['Lat'].mode() [0])
df2['Long']=df2['Long'].fillna(df2['Long'].mode() [0])

# %%
df.isna().sum()
# Out:
# Province/State    0
# Country/Region    0
# Lat               0
# Long              0
# 1/22/20           0
#                  ..
# 3/5/23            0
# 3/6/23            0
# 3/7/23            0
# 3/8/23            0
# 3/9/23            0
# Length: 1147, dtype: int64

# %%
confirmed=df.iloc[:,4:].sum().head(1143)

# %%
confirmed
# Out:
# 1/22/20          557
# 1/23/20          657
# 1/24/20          944
# 1/25/20         1437
# 1/26/20         2120
#              ...
# 3/5/23     676024901
# 3/6/23     676082941
# 3/7/23     676213378
# 3/8/23     676392824
# 3/9/23     676570149
# Length: 1143, dtype: int64

# %%
deadth = df2.iloc[:,4:].sum()

# %%
deadth
# Out:
# 1/22/20         17
# 1/23/20         18
# 1/24/20         26
# 1/25/20         42
# 1/26/20         56
#             ...
# 3/5/23     6877749
# 3/6/23     6878115
# 3/7/23     6879038
# 3/8/23     6880483
# 3/9/23     6881802
# Length: 1143, dtype: int64

# %%
covid_df = pd.DataFrame({'date': confirmed.index, 'confirmed': confirmed.values,'total_dead':deadth.values}).reset_index(drop = True)

# %%
stock.tail(20)
# Out:
#      2. high  3. low                 date
# 783   339.08  337.48  2020-02-19 00:00:00
# 784   337.67  335.21  2020-02-18 00:00:00
# 785   337.73  336.20  2020-02-14 00:00:00
# 786   338.12  335.56  2020-02-13 00:00:00
# 787   337.65  336.43  2020-02-12 00:00:00
# 788   337.02  334.68  2020-02-11 00:00:00
# 789   334.75  331.19  2020-02-10 00:00:00
# 790   333.99  331.60  2020-02-07 00:00:00
# 791   334.19  332.80  2020-02-06 00:00:00
# 792   333.09  330.67  2020-02-05 00:00:00
# 793   330.01  327.72  2020-02-04 00:00:00
# 794   326.16  323.22  2020-02-03 00:00:00
# 795   327.17  320.73  2020-01-31 00:00:00
# 796   327.91  323.54  2020-01-30 00:00:00
# 797   328.63  326.40  2020-01-29 00:00:00
# 798   327.85  323.60  2020-01-28 00:00:00
# 799   325.12  322.66  2020-01-27 00:00:00
# 800   332.53  327.36  2020-01-24 00:00:00
# 801   332.17  329.41  2020-01-23 00:00:00
# 802   332.95  331.17  2020-01-22 00:00:00

# %%
covid_df.head(20)
# Out:
#        date  confirmed  total_dead
# 0   1/22/20        557          17
# 1   1/23/20        657          18
# 2   1/24/20        944          26
# 3   1/25/20       1437          42
# 4   1/26/20       2120          56
# 5   1/27/20       2929          82
# 6   1/28/20       5580         131
# 7   1/29/20       6169         133
# 8   1/30/20       8237         172
# 9   1/31/20       9927         214
# 10   2/1/20      12038         260
# 11   2/2/20      16787         364
# 12   2/3/20      19887         428
# 13   2/4/20      23899         494
# 14   2/5/20      27644         566
# 15   2/6/20      30806         636
# 16   2/7/20      34400         721
# 17   2/8/20      37131         808
# 18   2/9/20      40162         908
# 19  2/10/20      42771        1015

# %%
covid = pd.merge(covid_df,stock,on='date',how='right')

covid=covid.reset_index(drop = True)
covid
# Out:
#                     date  confirmed  total_dead  2. high  3. low
# 0    2023-03-29 00:00:00        NaN         NaN   401.60  398.68
# 1    2023-03-28 00:00:00        NaN         NaN   396.49  393.69
# 2    2023-03-27 00:00:00        NaN         NaN   398.92  395.56
# 3    2023-03-24 00:00:00        NaN         NaN   395.84  389.40
# 4    2023-03-23 00:00:00        NaN         NaN   399.29  390.35
# ..                   ...        ...         ...      ...     ...
# 798  2020-01-28 00:00:00        NaN         NaN   327.85  323.60
# 799  2020-01-27 00:00:00        NaN         NaN   325.12  322.66
# 800  2020-01-24 00:00:00        NaN         NaN   332.53  327.36
# 801  2020-01-23 00:00:00        NaN         NaN   332.17  329.41
# 802  2020-01-22 00:00:00        NaN         NaN   332.95  331.17
#
# [803 rows x 5 columns]

# %%
covid['confirmed']=covid['confirmed'].fillna(covid['confirmed'].mode()[0])
covid['total_dead']=covid['total_dead'].fillna(covid['total_dead'].mode()[0])

# %%
covid.isna().sum()
# Out:
# date            0
# confirmed     803
# total_dead    803
# 2. high         0
# 3. low          0
# dtype: int64

# %%
covid=covid.rename(columns={'2. high':'stock_high','3. low':'stock_low'})

# %%
covid
# Out:
#                     date  confirmed  total_dead  2. high  3. low
# 0    2023-03-29 00:00:00        NaN         NaN   401.60  398.68
# 1    2023-03-28 00:00:00        NaN         NaN   396.49  393.69
# 2    2023-03-27 00:00:00        NaN         NaN   398.92  395.56
# 3    2023-03-24 00:00:00        NaN         NaN   395.84  389.40
# 4    2023-03-23 00:00:00        NaN         NaN   399.29  390.35
# ..                   ...        ...         ...      ...     ...
# 798  2020-01-28 00:00:00        NaN         NaN   327.85  323.60
# 799  2020-01-27 00:00:00        NaN         NaN   325.12  322.66
# 800  2020-01-24 00:00:00        NaN         NaN   332.53  327.36
# 801  2020-01-23 00:00:00        NaN         NaN   332.17  329.41
# 802  2020-01-22 00:00:00        NaN         NaN   332.95  331.17
#
# [803 rows x 5 columns]

# %%
fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(12, 10))
ax1.plot(covid['date'], covid['stock_high'], label='High')
ax1.plot(covid['date'], covid['stock_low'], label='Low')
ax1.set_xlabel('Date')
ax1.set_ylabel('Stock Price')
ax1.set_title('Daily High and Low Prices')
ax1.legend()
ax2.bar(covid['date'], covid['confirmed'], label='Confirmed Cases')
ax2.bar(covid['date'], covid['total_dead'], label='Total Deaths')
ax2.set_xlabel('Date')
ax2.set_ylabel('Number of Cases/Deaths')
ax2.set_title('COVID-19 Cases and Deaths')
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'stock_high'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24340\843161284.py in <module>
#       1 fig, (ax1,ax2) = plt.subplots(2, 1, figsize=(12, 10))
# ----> 2 ax1.plot(covid['date'], covid['stock_high'], label='High')
#       3 ax1.plot(covid['date'], covid['stock_low'], label='Low')
#       4 ax1.set_xlabel('Date')
#       5 ax1.set_ylabel('Stock Price')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'stock_high'
